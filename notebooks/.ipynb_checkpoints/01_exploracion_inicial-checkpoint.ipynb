# %%
import pandas as pd
import numpy as np

# %%
rng = np.random.default_rng(42)

df = pd.DataFrame({
    "ventas": rng.integers(100, 500, 10),
    "clientes": rng.integers(10, 50, 10)
})

df.head()
# Out:
#    ventas  clientes
# 0     135        31
# 1     409        49
# 2     361        39
# 3     275        40
# 4     273        38

# %%
print("shape:", df.shape)
df.describe()
# Out:
# shape: (10, 2)
#            ventas   clientes
# count   10.000000  10.000000
# mean   272.500000  35.400000
# std    120.957522   9.628661
# min    134.000000  15.000000
# 25%    147.750000  30.250000
# 50%    274.000000  38.500000
# 75%    373.750000  40.750000
# max    443.000000  49.000000
